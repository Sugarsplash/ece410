# %% [markdown]
# by William Harrington
#
# ## Intro
#
# The purpose of this notebook is to explore using pandas for analyzing the historical data of a stock.

# %%
import pandas_datareader.data as web
import datetime

start = datetime.datetime(1993, 2, 1)
end = datetime.datetime(2015, 5, 14)

f = web.DataReader("SPY", 'yahoo', start, end)

import matplotlib.pylab as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats

# Graphing helper function
def setup_graph(title='',x_label='', y_label='', fig_size=None):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0],
                            fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# %%
setup_graph('SPY Historical Data (Open)', 'Date', 'Value', (9,6.5))
f['Open'].plot()

# %%
setup_graph('SPY Historical Data (Close)', 'Date', 'Value', (9,6.5))
f['Close'].plot()

# %%
setup_graph('SPY Historical Data (High)', 'Date', 'Value', (9,6.5))
f['High'].plot()

# %%
setup_graph('SPY Historical Data (Low)', 'Date', 'Value', (9,6.5))
f['Low'].plot()
