# %% [markdown]
# by William Harrington
#
# ## Intro
#
# Purpose of this notebook is to explore using octave within an ipython notebook.

# %%
from oct2py import octave

# this is the path of the code I wish to use
octave.addpath('~/Desktop/ECE410/Code/option_sim/')

# call the script
octave.eval('option_sim')
# Out:
# spy_first_date =  19930129.00
# spy_last_date =  20150514.00
# vix_first_date =  19900102.00
# vix_last_date =  20150514.00
# # Month_1   Strike  Value_in   Date_out_f  Date_out     Value_out  Prft  Days_held
# ...
# 1:	19930201	44	    2.30	19930319	19930318	   1.32	   0.99		45
# 2:	19930301	44	    3.44	19930416	19930415	   0.94	   2.50		45
# 3:	19930401	45	    2.95	19930521	19930520	   0.48	   2.47		49
# 4:	19930503	44	    2.59	19930618	19930617	   1.19	   1.40		45
# 5:	19930601	46	    2.50	19930716	19930715	   1.12	   1.38		44
# 6:	19930701	45	    2.46	19930820	19930819	   0.83	   1.63		49
# 7:	19930802	45	    2.07	19930917	19930916	   1.21	   0.86		45
# 8:	19930901	47	    3.75	19931015	19931014	   0.60	   3.15		43
# 9:	19931001	46	    4.01	19931119	19931118	   0.63	   3.38		48
# 10:	19931101	47	    3.73	19931217	19931216	   0.52	   3.21		45
# 11:	19931201	46	    4.21	19940121	19940120	   1.47	   2.74		50
# 12:	19940103	46	    2.94	19940218	19940217	   1.17	   1.77		45
# ...
